# %%
import pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.read_csv("\data\Homicidios_2018.csv")
# Out:
#                        Fecha Departamento            Municipio        Día  \
# 0     01/01/2018 12:00:00 AM     AMAZONAS         LETICIA (CT)      Lunes
# 1     01/01/2018 12:00:00 AM     AMAZONAS         LETICIA (CT)      Lunes
# 2     01/01/2018 12:00:00 AM    ANTIOQUIA                ANDES      Lunes
# 3     01/01/2018 12:00:00 AM    ANTIOQUIA                ANDES      Lunes
# 4     01/01/2018 12:00:00 AM    ANTIOQUIA                ANORÍ      Lunes
# ...                      ...          ...                  ...        ...
# 4961  12/12/2018 12:00:00 AM    SANTANDER      BARRANCABERMEJA  Miércoles
# 4962  12/12/2018 12:00:00 AM        VALLE            CALI (CT)  Miércoles
# 4963  12/12/2018 12:00:00 AM        VALLE            CALI (CT)  Miércoles
# 4964  12/12/2018 12:00:00 AM        VALLE  GUADALAJARA DE BUGA  Miércoles
# 4965                     NaN          NaN                  NaN        NaN
#
#           Hora                   Barrio    Zona               Clase de sitio  \
# ...

# %%
Homicidios_df = pd.read_csv("\data\Homicidios_2018.csv")

# %%
Homicidios_df
# Out:
#                        Fecha Departamento            Municipio        Día  \
# 0     01/01/2018 12:00:00 AM     AMAZONAS         LETICIA (CT)      Lunes
# 1     01/01/2018 12:00:00 AM     AMAZONAS         LETICIA (CT)      Lunes
# 2     01/01/2018 12:00:00 AM    ANTIOQUIA                ANDES      Lunes
# 3     01/01/2018 12:00:00 AM    ANTIOQUIA                ANDES      Lunes
# 4     01/01/2018 12:00:00 AM    ANTIOQUIA                ANORÍ      Lunes
# ...                      ...          ...                  ...        ...
# 4961  12/12/2018 12:00:00 AM    SANTANDER      BARRANCABERMEJA  Miércoles
# 4962  12/12/2018 12:00:00 AM        VALLE            CALI (CT)  Miércoles
# 4963  12/12/2018 12:00:00 AM        VALLE            CALI (CT)  Miércoles
# 4964  12/12/2018 12:00:00 AM        VALLE  GUADALAJARA DE BUGA  Miércoles
# 4965                     NaN          NaN                  NaN        NaN
#
#           Hora                   Barrio    Zona               Clase de sitio  \
# ...

# %%
Homicidios_df.head()
# Out:
#                     Fecha Departamento     Municipio    Día     Hora  \
# 0  01/01/2018 12:00:00 AM     AMAZONAS  LETICIA (CT)  Lunes  9:45:00
# 1  01/01/2018 12:00:00 AM     AMAZONAS  LETICIA (CT)  Lunes  9:45:00
# 2  01/01/2018 12:00:00 AM    ANTIOQUIA         ANDES  Lunes  8:30:00
# 3  01/01/2018 12:00:00 AM    ANTIOQUIA         ANDES  Lunes  2:30:00
# 4  01/01/2018 12:00:00 AM    ANTIOQUIA         ANORÍ  Lunes  3:30:00
#
#              Barrio    Zona               Clase de sitio  \
# 0         ESPERANZA  URBANA                VIAS PUBLICAS
# 1         ESPERANZA  URBANA                VIAS PUBLICAS
# 2   ALTO DEL CEDRON   RURAL                VIAS PUBLICAS
# 3  PARQUE PRINCIPAL   RURAL                      PARQUES
# 4            TENCHE   RURAL  BARES, CANTINAS Y SIMILARES
#
#                  Arma empleada Móvil Agresor Móvil Victima  Edad       Sexo  \
# 0  ARMA BLANCA / CORTOPUNZANTE         A PIE         A PIE  16.0  MASCULINO
# ...

# %%
type(Homicidios_df)
# Out:
# pandas.core.frame.DataFrame

# %%
Homicidios_df.dtypes
# Out:
# Fecha                  object
# Departamento           object
# Municipio              object
# Día                    object
# Hora                   object
# Barrio                 object
# Zona                   object
# Clase de sitio         object
# Arma empleada          object
# Móvil Agresor          object
# Móvil Victima          object
# Edad                  float64
# Sexo                   object
# Estado civil           object
# País de nacimiento     object
# Clase de empleado      object
# Profesión              object
# Escolaridad            object
# Código DANE           float64
# Cantidad                int64
# dtype: object

# %%
pip install --upgrade google-cloud-bigquery[pandas]
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for google-crc32c: filename=google_crc32c-0.1.0-py3-none-any.whl size=9818 sha256=91801a49692ac7b77b82a36bceff4e1f4e1940fa1595f2828b55525b46590543
#   Stored in directory: c:\users\saracmque\appdata\local\pip\cache\wheels\2a\2e\73\c2bfa476c8ec3655ceb5acccf6adc774c8356a2a8fedf123ff
# Successfully built google-crc32c
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
¿Qué problemas de calidad de los datos evidencia?

# %%
Campos tipo fecha no tienen el formato por ejemplo campo fecha.

# %%
Formato de hora para campo hora no se tiene un formato de hora.

# %%
Entendiendo que los datos de barrio,zona,etc estàn los datos del maestros y muestra su descripciòn. Sino estos deben tener un id para cada maestro y mostrar la descripciòn del campo.

# %%
Existen lineas sin datos

# %%
 ¿Cómo podrías resolverlos?

# %%
Realizar una mineria de datos, y con BigQuery con where donde columnas no esten en null Y DAR FORMATO  campos de fecha y hora.

# %%
Dar formato de fecha y hora a estos campos

# %%
Entendiendo que los datos de barrio,zona,etc estàn los datos del maestros y muestra su descripciòn. Sino estos deben tener un id para cada maestro y mostrar la descripciòn del campo.

# %%
 algunas consultas en SQL para explorar los datos en Bigquery

# %%
BigQuery con where donde columnas no esten en null Y DAR FORMATO  campos de fecha y hora.

# %%
# %load_ext google.cloud.bigquery

# %%
Homicidios_df.columns
# Out:
# Index(['Fecha', 'Departamento', 'Municipio', 'Día', 'Hora', 'Barrio', 'Zona',
#        'Clase de sitio', 'Arma empleada', 'Móvil Agresor', 'Móvil Victima',
#        'Edad', 'Sexo', 'Estado civil', 'País de nacimiento',
#        'Clase de empleado', 'Profesión', 'Escolaridad', 'Código DANE',
#        'Cantidad'],
#       dtype='object')

# %%
grouped_data = Homicidios_df.groupby('Municipio')

# %%
species_counts = Homicidios_df.groupby('Municipio')['Cantidad'].count()
print(species_counts)
# Out:
# Municipio
# ABREGO            2
# ACACÍAS           6
# ACANDÍ            7
# ACEVEDO           4
# ACHÍ              2
#                  ..
# YUMBO            37
# ZARAGOZA          7
# ZARZAL            9
# ZIPAQUIRÁ         2
# ZONA BANANERA    11
# Name: Cantidad, Length: 582, dtype: int64

# %%
⦁ ¿Cuáles fueron los principales municipios con mayor cantidad de asesinatos por mes?
# Out:
# Object `mes` not found.

# %%
⦁ ¿Cuáles fueron los principales municipios con mayor cantidad de asesinatos por mes

# %%
YUMBO             37 y ZONA BANANERA    11

# %%
Para Bogotá, qué barrios reportaron mayor cantidad de asesinatos entre las 6 de la noche y las 12 de la noche.

# %%
ALBANIA E-3                           18:00:00    1

VISTA HERMOSA SECTOR EL ESPINAL E-19  20:10:00    1

Sin descripciòn de barrio tenemos estos:
                                      21:20:00    1
                                      21:40:00    1

# %%
species_counts = Homicidios_df.groupby('Barrio')['Municipio'].count()
print(species_counts)
# Out:
# Barrio
# 07 DE AGOSTO         1
# 1 DE MAYO            2
# 11 DE ABRIL          1
# 11 DE NOVIEMBRE      2
# 12 DE OCTUBRE        1
#                     ..
# ZONA CENTRO          4
# ZONA INDUSTRIAL      3
# ZONA RURAL           4
# ZONA TOLERANCIA      1
# ZUNGO EMBARCADERO    1
# Name: Municipio, Length: 2947, dtype: int64

# %%
grouped_data.describe()
# Out:
#                Edad                                                        \
#               count       mean        std   min    25%   50%    75%   max
# Municipio
# ABREGO          2.0  41.000000  25.455844  23.0  32.00  41.0  50.00  59.0
# ACACÍAS         6.0  28.333333   7.257180  15.0  27.25  29.5  33.25  35.0
# ACANDÍ          7.0  32.000000   5.773503  24.0  30.00  31.0  33.00  43.0
# ACEVEDO         4.0  48.250000  18.246004  26.0  38.75  49.0  58.50  69.0
# ACHÍ            2.0  36.000000   8.485281  30.0  33.00  36.0  39.00  42.0
# ...             ...        ...        ...   ...    ...   ...    ...   ...
# YUMBO          37.0  27.162162  10.210326   5.0  21.00  25.0  29.00  50.0
# ZARAGOZA        7.0  31.142857   9.668309  20.0  22.00  35.0  38.00  43.0
# ZARZAL          9.0  35.444444  12.340088  22.0  27.00  31.0  45.00  59.0
# ZIPAQUIRÁ       2.0  28.000000   9.899495  21.0  24.50  28.0  31.50  35.0
# ...

# %%
¿Qué otros conocimientos puede extraer de este conjunto de datos?

# %%
grouped_data2 = Homicidios_df.groupby(['Municipio','Hora'])

# %%
grouped_data2.mean()
# Out:
#                         Edad  Código DANE  Cantidad
# Municipio     Hora
# ABREGO        10:30:00  59.0   54003000.0       1.0
#               23:08:00  23.0   54003000.0       1.0
# ACACÍAS       16:45:00  31.0   50006000.0       1.0
#               1:40:00   35.0   50006000.0       1.0
#               23:05:00  31.0   50006000.0       1.0
# ...                      ...          ...       ...
# ZONA BANANERA 1:50:00   55.0   47980000.0       1.0
#               22:40:00  39.0   47980000.0       1.0
#               5:00:00   30.0   47980000.0       1.0
#               7:00:00   28.0   47980000.0       1.0
#               7:15:00   32.0   47980000.0       1.0
#
# [4129 rows x 3 columns]

# %%
Homicidios_df.groupby(['Municipio','Barrio','Hora'])['Hora'].count()['BOGOTÁ D.C. (CT)']
# Out:
# Barrio                                Hora
# ACIP E-8                              15:30:00    1
# ALBANIA E-3                           18:00:00    1
# ALCALA E-16                           13:30:00    1
# ALFA E-19                             14:15:00    1
# ALQUERIAS DE LA FRAGUA E-8            16:14:00    1
#                                                  ..
# VISTA HERMOSA SECTOR EL ESPINAL E-19  20:10:00    1
# VITELMA E-4                           11:00:00    1
# VOTO NACIONAL E-14                    15:15:00    1
#                                       21:20:00    1
#                                       21:40:00    1
# Name: Hora, Length: 419, dtype: int64

# %%
¿Tendría sentido un modelo de aprendizaje automático para apoyar a la fuerza policial en su trabajo?

# %%
Claroque si, es de utilidad para su labor.

# %%
¿Qué tipo de modelo elegiría (regresión, clasificación, agrupamiento)?

# %%
Agrupamiento

# %%
¿Cómo implementaría su modelo? Proponer una arquitectura y explicarla.
